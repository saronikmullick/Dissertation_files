# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ICE_Correlation_Dataset.csv')

# %%
correlation_matrix = df[['Total ICE sales : Petrol + Diesel', 'Petrol (pence/litre)', 'Diesel (pence/litre)']].corr()

print("Correlation Matrix:\n")
print(correlation_matrix)

#heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap: ICE Sales vs Fuel Prices")
plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix:
#
#                                    Total ICE sales : Petrol + Diesel  \
# Total ICE sales : Petrol + Diesel                           1.000000
# Petrol (pence/litre)                                       -0.544580
# Diesel (pence/litre)                                       -0.523576
#
#                                    Petrol (pence/litre)  Diesel (pence/litre)
# Total ICE sales : Petrol + Diesel             -0.544580             -0.523576
# Petrol (pence/litre)                           1.000000              0.996305
# Diesel (pence/litre)                           0.996305              1.000000
